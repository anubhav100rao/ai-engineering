# %%
import torch
import torch.nn as nn

layer = nn.Linear(3, 2)
x = torch.tensor([[1.0, 2.0, 3.0]])
out = layer(x)
print(out)
print(out.shape)
# Out:
# tensor([[-0.4081, -0.6982]], grad_fn=<AddmmBackward0>)
# torch.Size([1, 2])

# %%
for name, param in layer.named_parameters():
    print(name, param.shape)
# Out:
# weight torch.Size([2, 3])
# bias torch.Size([2])
